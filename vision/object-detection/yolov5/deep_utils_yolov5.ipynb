# %% [markdown]
# <a href="https://colab.research.google.com/github/pooya-mohammadi/deep-utils-notebooks/blob/main/vision/object-detection/yolov5/deep_utils_yolov5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep-Utils
# ## A toolkit for deep-learning practitioners!
#
# This reposito
# ry contains the most frequently used deep learning models and functions. Deep_Utils is still under heavy development, so take into consideration that many features may change in the future. Install the latest version using pypi.

# %% [markdown]
# # Installation

# %%
# !pip install deep_utils[torch]
# Out:
# Requirement already satisfied: deep_utils[torch] in /home/ai/miniconda3/envs/torch_gpu/lib/python3.9/site-packages (0.8.23)
# Requirement already satisfied: requests>=2.27.1 in /home/ai/miniconda3/envs/torch_gpu/lib/python3.9/site-packages (from deep_utils[torch]) (2.27.1)
# Requirement already satisfied: numpy>=1.21.0 in /home/ai/miniconda3/envs/torch_gpu/lib/python3.9/site-packages (from deep_utils[torch]) (1.21.2)
# Requirement already satisfied: tqdm>=4.62.3 in /home/ai/miniconda3/envs/torch_gpu/lib/python3.9/site-packages (from deep_utils[torch]) (4.62.3)
# Requirement already satisfied: torchvision>=0.10.0 in /home/ai/miniconda3/envs/torch_gpu/lib/python3.9/site-packages (from deep_utils[torch]) (0.11.3)
# Requirement already satisfied: opencv-python>=4.5.5.58 in /home/ai/miniconda3/envs/torch_gpu/lib/python3.9/site-packages (from deep_utils[torch]) (4.5.5.64)
# Requirement already satisfied: torch>=1.8.0 in /home/ai/miniconda3/envs/torch_gpu/lib/python3.9/site-packages (from deep_utils[torch]) (1.10.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ai/miniconda3/envs/torch_gpu/lib/python3.9/site-packages (from requests>=2.27.1->deep_utils[torch]) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ai/miniconda3/envs/torch_gpu/lib/python3.9/site-packages (from requests>=2.27.1->deep_utils[torch]) (1.26.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/ai/miniconda3/envs/torch_gpu/lib/python3.9/site-packages (from requests>=2.27.1->deep_utils[torch]) (2.0.11)
# Requirement already satisfied: idna<4,>=2.5 in /home/ai/miniconda3/envs/torch_gpu/lib/python3.9/site-packages (from requests>=2.27.1->deep_utils[torch]) (3.3)
# Requirement already satisfied: typing_extensions in /home/ai/miniconda3/envs/torch_gpu/lib/python3.9/site-packages (from torch>=1.8.0->deep_utils[torch]) (3.10.0.2)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /home/ai/miniconda3/envs/torch_gpu/lib/python3.9/site-packages (from torchvision>=0.10.0->deep_utils[torch]) (8.4.0)

# %% [markdown]
# ## YOLOV5-Pytorch

# %%
from deep_utils import YOLOV5TorchObjectDetector

# %% [markdown]
# ## Create an object detection model using YOLOV5s
# The default Yolov5s will be downloaded automatically if there are no trained weights available!

# %%
yolov5 = YOLOV5TorchObjectDetector()
# Out:
# Fusing layers...
# Model Summary: 213 layers, 7225885 parameters, 0 gradients
# YOLOV5TorchObjectDetector: weights are loaded

# %% [markdown]
# # Check the input config
# All the config parameters can be changed as input arguments to the `YOLOV5TorchObjectDetector` class.

# %%
yolov5
# Out:
# YOLOV5TorchObjectDetector config attributes:
# class_names = ['person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus', 'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed', 'dining table', 'toilet', 'tv', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush']
# confidence = 0.4
# device = cpu
# img_size = (320, 320)
# iou_thresh = 0.45
# model_weight = yolov5s.pt

# %% [markdown]
# # Download the test image

# %%
import cv2
from deep_utils import Box, download_file, Point
from PIL import Image

# Download an image
download_file("https://raw.githubusercontent.com/pooya-mohammadi/deep-utils-notebooks/main/vision/images/dog.jpg")

# Load an image
base_image = cv2.imread("dog.jpg")

# pil.Image is used for visualization
Image.fromarray(base_image[...,::-1]) # convert to rgb
# Out:
# [INFO] Downloading data from https://raw.githubusercontent.com/pooya-mohammadi/deep-utils-notebooks/main/vision/images/dog.jpg
# [██████████████████████████████████████████████████]
# <PIL.Image.Image image mode=RGB size=768x576 at 0x7FA841DBBBE0>

# %% [markdown]
# # Detect Objects

# %%
# Detect the objects
# the image is opened by cv2 which results to a BGR image. Therefore the `is_rgb` is set to `False` 
result = yolov5.detect_objects(base_image, is_rgb=False, confidence=0.5)

# Draw detected boxes on the image.
img = Box.put_box_text(base_image,
                       box=result.boxes,
                       label=[f"{c_n} {c}" for c_n, c in zip(result.class_names, result.confidences)])

# pil.Image is used for visualization
Image.fromarray(img[...,::-1]) # convert to rgb
# Out:
# <PIL.Image.Image image mode=RGB size=768x576 at 0x7FA841DBBD30>

# %% [markdown]
# ## Detecting with a pretrained model or other yolov5 models

# %%
# Pass your weight's address which mainly ends with `.pt` as `model_weight` argument and your class_names as well.
model_weight = "yolov5m.pt"
class_names = ['person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus',
               'train', 'truck', 'boat', 'traffic light', 'fire hydrant',
               'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog',
               'horse', 'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe',
               'backpack', 'umbrella', 'handbag', 'tie', 'suitcase', 'frisbee',
               'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove', 
               'skateboard', 'surfboard', 'tennis racket', 'bottle', 'wine glass',
               'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich',
               'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake',
               'chair', 'couch', 'potted plant', 'bed', 'dining table', 'toilet', 'tv',
               'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave', 'oven',
               'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors',
               'teddy bear', 'hair drier', 'toothbrush']
yolov5 = YOLOV5TorchObjectDetector(model_weight=model_weight, class_names=class_names)
yolov5
# Out:
# Fusing layers...
# Model Summary: 290 layers, 21172173 parameters, 0 gradients
# YOLOV5TorchObjectDetector: weights are loaded
# YOLOV5TorchObjectDetector config attributes:
# class_names = ['person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus', 'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed', 'dining table', 'toilet', 'tv', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush']
# confidence = 0.4
# device = cpu
# img_size = (320, 320)
# iou_thresh = 0.45
# model_weight = yolov5m.pt

# %%
import cv2
from deep_utils import Box, download_file, Point
from PIL import Image

result = yolov5.detect_objects(base_image, is_rgb=False, confidence=0.5)

# Draw detected boxes on the image.
img = Box.put_box_text(base_image,
                       box=result.boxes,
                       label=[f"{c_n} {c}" for c_n, c in zip(result.class_names, result.confidences)])

# pil.Image is used for visualization
Image.fromarray(img[...,::-1]) # convert to rgb
# Out:
# <PIL.Image.Image image mode=RGB size=768x576 at 0x7FA841D8F400>

# %%
# save image!
cv2.imwrite("../../images/dog_yolov5.jpg", img)
# Out:
# True

# %% [markdown]
# # Check out our repo
# [link https://github.com/pooya-mohammadi/deep_utils](https://https://github.com/pooya-mohammadi/deep_utils)
#
# # Please **star** the repo
